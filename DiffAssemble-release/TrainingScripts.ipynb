# %%
# %run puzzle_diff/train_script.py
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~/DiffAssemble-release/DiffAssemble-release/puzzle_diff/train_script.py in <module>
#       3 import sys
#       4 import glob
# ----> 5 import torch_geometric
#       6
#       7 sys.path.append(os.path.join(os.path.dirname(__file__), "lib"))
#
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
pip install torch_geometric
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.1/63.1 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.8 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 17.8 MB/s eta 0:00:00
# ...
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/apps/jupyterhub/COMP52715/lib/python3.11/site-packages/psutil'
# Check the permissions.
#
#
# [notice] A new release of pip is available: 23.3.2 -> 25.1.1
# [notice] To update, run: /apps/jupyterhub/COMP52715/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import networkx as nx
from torch_geometric.datasets import TUDataset
from torch_geometric.loader import DataLoader
from torch_geometric.utils import to_networkx

# Load a dataset (e.g., ENZYMES)
dataset = TUDataset(root='/tmp/ENZYMES', name='ENZYMES')

# Create a DataLoader
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# Get one batch
batch = next(iter(loader))

# Convert batch to individual graphs
graphs = batch.to_data_list()

# Plot each graph
fig, axes = plt.subplots(1, len(graphs), figsize=(15, 5))
for i, data in enumerate(graphs):
    G = to_networkx(data, to_undirected=True)
    nx.draw(G, ax=axes[i], with_labels=True, node_size=50)
    axes[i].set_title(f"Graph {i+1}")

plt.tight_layout()
plt.show()
